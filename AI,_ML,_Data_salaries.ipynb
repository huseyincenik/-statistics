# %% [markdown]
# <a href="https://colab.research.google.com/github/huseyincenik/statistics/blob/main/AI%2C_ML%2C_Data_salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('salaries.csv')

# %% [markdown]
# Introduction
#
# 💬 "Salary for AI, ML Data jobs" is one of the fascinating practical topics, currently receiving great attention from the community of people studying and working in the field of Data Science.
#
# Helping those interested in the field of Data Science:
#
# Get an overview of the changes in this field from 2020 to the present.
#
# Capture the trend of working and salary between industries going on in the world.
#
# Provide a lot of useful information to give directions on future work.
#
# About dataset
#
# The data source is available with a worldwide contribution size, being collected and updated continuously from 2020 to the present time (usually on a weekly basis). The dataset is published in the public domain, users can access and download the dataset easily.
#
# Column meaning
#
# work_year: The year the salary was paid.
#
# experience_level: The experience level in the job during the year with the following possible values
#
# EN Entry-level
#
# MI Junior Mid-level
#
# SE Intermediate Senior-level
#
# EX Expert Executive-level / Director
#
# employment_type: The type of employment for the role
#
# PT Part-time
#
# FT Full-time
#
# CT Contract
#
# FL Freelance
#
# job_title: The role worked in during the year.
#
# salary: The total gross salary amount paid.
#
# salary_currency: The currency of the salary paid as an ISO 4217 currency code.
#
# salary_in_usd: The salary in USD (FX rate divided by avg. USD rate for the respective year via fxdata.foorilla.com.
#
# employee_residence: Employee's primary country of residence in during the work year as an ISO 3166 country code.
#
# remote_ratio: The overall amount of work done remotely, possible values are as follows
#
# 0 No remote work (less than 20%)
#
# 50 Partially remote
#
# 100 Fully remote (more than 80%)
#
# company_location: The country of the employer's main office or contracting
# branch as an ISO 3166 country code.
#
# company_size: The average number of people that worked for the company during
# the year
#
# S less than 50 employees (small)
#
# M 50 to 250 employees (medium)
#
# L more than 250 employees (large)
#
# https://www.kaggle.com/datasets/nguyenthicamlai/ai-ml-data-salaries

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              FT        AWS Data Architect
# 1          2023               SE              FT            Data Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT             Data Engineer
# 4          2023               SE              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 4129       2020               SE              FT            Data Scientist
# 4130       2021               MI              FT  Principal Data Scientist
# 4131       2020               EN              FT            Data Scientist
# 4132       2020               EN              CT     Business Data Analyst
# 4133       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           4134 non-null   int64
#  1   experience_level    4134 non-null   object
#  2   employment_type     4134 non-null   object
#  3   job_title           4134 non-null   object
#  4   salary              4134 non-null   int64
#  5   salary_currency     4134 non-null   object
#  6   salary_in_usd       4134 non-null   int64
#  7   employee_residence  4134 non-null   object
#  8   remote_ratio        4134 non-null   int64
#  9   company_location    4134 non-null   object
#  10  company_size        4134 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 355.4+ KB

# %%
df.head(5)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2023               MI              FT  AWS Data Architect  258000
# 1       2023               SE              FT      Data Scientist  225000
# 2       2023               SE              FT      Data Scientist  156400
# 3       2023               SE              FT       Data Engineer  190000
# 4       2023               SE              FT       Data Engineer  150000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         258000                 US           100
# 1             USD         225000                 US             0
# 2             USD         156400                 US             0
# 3             USD         190000                 US           100
# 4             USD         150000                 US           100
#
#   company_location company_size
# 0               US            L
# 1               US            M
# ...

# %%
df.isnull().sum() # Features with a value of 0
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           4134 non-null   int64
#  1   experience_level    4134 non-null   object
#  2   employment_type     4134 non-null   object
#  3   job_title           4134 non-null   object
#  4   salary              4134 non-null   int64
#  5   salary_currency     4134 non-null   object
#  6   salary_in_usd       4134 non-null   int64
#  7   employee_residence  4134 non-null   object
#  8   remote_ratio        4134 non-null   int64
#  9   company_location    4134 non-null   object
#  10  company_size        4134 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 355.4+ KB

# %%
df.dropna()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              FT        AWS Data Architect
# 1          2023               SE              FT            Data Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT             Data Engineer
# 4          2023               SE              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 4129       2020               SE              FT            Data Scientist
# 4130       2021               MI              FT  Principal Data Scientist
# 4131       2020               EN              FT            Data Scientist
# 4132       2020               EN              CT     Business Data Analyst
# 4133       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           4134 non-null   int64
#  1   experience_level    4134 non-null   object
#  2   employment_type     4134 non-null   object
#  3   job_title           4134 non-null   object
#  4   salary              4134 non-null   int64
#  5   salary_currency     4134 non-null   object
#  6   salary_in_usd       4134 non-null   int64
#  7   employee_residence  4134 non-null   object
#  8   remote_ratio        4134 non-null   int64
#  9   company_location    4134 non-null   object
#  10  company_size        4134 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 355.4+ KB

# %%
df.work_year.unique()
# Out:
# array([2023, 2022, 2021, 2020])

# %%
df.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.job_title.unique()
# Out:
# array(['AWS Data Architect', 'Data Scientist', 'Data Engineer',
#        'Applied Scientist', 'ML Engineer', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Manager',
#        'Product Data Analyst', 'Autonomous Vehicle Operations Lead',
#        'Applied Machine Learning Engineer', 'Analytics Engineer',
#        'ETL Developer', 'Business Intelligence Engineer',
#        'BI Data Analyst', 'Machine Learning Developer',
#        'Research Engineer', 'Data Integration Specialist',
#        'Data Architect', 'BI Developer', 'Data Visualization Analyst',
#        'Head of Data', 'Autonomous Vehicle Technician', 'Data Modeler',
#        'Sales Data Analyst', 'Cloud Data Engineer',
#        'Finance Data Analyst', 'Research Scientist',
#        'Data Analytics Manager', 'Data Specialist',
#        'Data Operations Analyst', 'Director of Data Science',
#        'Data Science Manager', 'Data Science Lead',
#        'Machine Learning Scientist', 'AI Scientist',
# ...

# %%
df[df["job_title"]=="Data Scientist"]
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 1          2023               SE              FT  Data Scientist  225000
# 2          2023               SE              FT  Data Scientist  156400
# 5          2023               SE              FT  Data Scientist  196000
# 6          2023               SE              FT  Data Scientist  121000
# 7          2023               SE              FT  Data Scientist  219000
# ...         ...              ...             ...             ...     ...
# 4120       2020               MI              FT  Data Scientist  118000
# 4121       2020               MI              FT  Data Scientist  138350
# 4125       2021               MI              FT  Data Scientist  160000
# 4129       2020               SE              FT  Data Scientist  412000
# 4131       2020               EN              FT  Data Scientist  105000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
df[]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('veriler.csv')

# "Data Scientist" iş unvanına sahip çalışanların tecrübelerine göre gruplandırın
ds_exp = df[df['job_title'] == 'Data Scientist'].groupby(['experience_level']).size()

# pasta grafiği için boyutları belirleyin
labels = ds_exp.index
sizes = ds_exp.values

# pasta grafiğini çizin
fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# grafiği görüntüleyin
plt.show()

# What level of experience do you have the most?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('veriler.csv')

# "Data Scientist" iş unvanına sahip çalışanların tecrübelerine göre gruplandırın
ds_exp = df[df['job_title'] == 'Data Scientist'].groupby(['experience_level']).size()

# en yüksek tecrübeye sahip çalışanların dilimini patlatın
explode = [0.1 if label == ds_exp.idxmax() else 0 for label in ds_exp.index]

# pasta grafiği için boyutları belirleyin
labels = ds_exp.index
sizes = ds_exp.values

# pasta grafiğini çizin
fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(sizes, labels=labels, explode=explode, autopct='%1.1f%%', startangle=90)

# grafiği görüntüleyin
plt.show()
"""
The abbreviations "EN", "EX", "MI" and "SE" probably refer to the experience level of the employees.
 However, what these abbreviations mean depends on the data source, and different companies or data sources may use different abbreviations.

In general, these abbreviations are often interpreted as follows:

EN (Entry Level): Newly graduated or less experienced employees
EX (Experienced): Employees with intermediate experience
MI (Mid-Level): Employees with mid-to-high level experience
SE (Senior Level): Employees with high level of experience or managerial positions

"""

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('veriler.csv')

# "Data Scientist" iş unvanına sahip çalışanların tecrübelerine göre gruplandırın
ds_exp = df[df['job_title'] == 'Data Scientist'].groupby(['experience_level']).size()

# en yüksek tecrübeye sahip çalışanların dilimini patlatın

explode = [0.5 if label == ds_exp.idxmin() else 0 for label in ds_exp.index]

# pasta grafiği için boyutları belirleyin
labels = ds_exp.index
sizes = ds_exp.values

# pasta grafiğini çizin
fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(sizes, labels=labels, explode=explode, autopct='%1.1f%%', startangle=90)

# grafiği görüntüleyin
plt.show()

# %%
(df["job_title"]=="Data Scientist").sum()
# Out:
# 919

# %%
import pandas as pd

# df = pd.read_csv('veriler.csv')

# "Data Scientist" iş unvanına sahip çalışanların tecrübelerine göre gruplandırın
ds_exp = df[df['job_title'] == 'Data Scientist'].groupby(['experience_level']).size()

# tabloyu görüntüleyin
print(ds_exp)

""" 
It is not possible to make a definite interpretation as the meaning of each abbreviation may vary depending on the data source. 
However, considering that EN (Entry Level) positions are generally suitable for new graduates or employees with 1-2 years of experience,
 the following evaluations can be made as an approach:

EN (Entry Level): Employees with 0-2 years of experience
EX (Experienced): Employees with 2-5 years of experience
MI (Mid-Level): Employees with 5-10 years of experience
SE (Senior Level): Employees with more than 10 years of experience or in managerial positions.
"""
# Out:
# experience_level
# EN     63
# EX     14
# MI    170
# SE    672
# dtype: int64

# %%
# Create a new DataFrame with value counts of experience_level
exp_counts = df['experience_level'].value_counts()

# Convert value counts to list
values = exp_counts.values.tolist()

# Convert index (i.e. experience levels) to list
labels = exp_counts.index.tolist()

# Create a figure object of the size 12x6
fig = plt.figure(figsize=(12, 6))

# Add the bar chart
ax1 = fig.add_subplot(1, 2, 1)
ax1.bar(labels, values)
ax1.set_title('Experience Level - Bar Chart')

# Add the pie chart
ax2 = fig.add_subplot(1, 2, 2)
ax2.pie(values, labels=labels, autopct='%1.1f%%')
ax2.set_title('Experience Level - Pie Chart')

# Display the figure
plt.show()

# Which year has the most data? - experience Level - Bar Chart
# Which group has the most experience in total? experience Level - Pie Chart

# %%
sns.countplot(x="work_year", data=df); # bar and pie charts are used for categorical data.
# Simple bar chart calculating frequency ( count bar chart)
# Which year has the most data?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           4134 non-null   int64
#  1   experience_level    4134 non-null   object
#  2   employment_type     4134 non-null   object
#  3   job_title           4134 non-null   object
#  4   salary              4134 non-null   int64
#  5   salary_currency     4134 non-null   object
#  6   salary_in_usd       4134 non-null   int64
#  7   employee_residence  4134 non-null   object
#  8   remote_ratio        4134 non-null   int64
#  9   company_location    4134 non-null   object
#  10  company_size        4134 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 355.4+ KB

# %%
import seaborn as sns

# Create a new DataFrame with value counts of experience_level
exp_counts = df['experience_level'].value_counts()

# Convert value counts to list
values = exp_counts.values.tolist()

# Convert index (i.e. experience levels) to list
labels = exp_counts.index.tolist()

# Create a figure object of the size 18x6
fig = plt.figure(figsize=(18, 6))

# Add the bar chart
ax1 = fig.add_subplot(1, 3, 1)
ax1.bar(labels, values)
ax1.set_title('Bar Chart')

# Add the pie chart
ax2 = fig.add_subplot(1, 3, 2)
ax2.pie(values, labels=labels, autopct='%1.1f%%')
ax2.set_title('Pie Chart')

# Add the bar plot
ax3 = fig.add_subplot(1, 3, 3)
sns.barplot(x="experience_level", y="salary", data=df, ax=ax3)
ax3.set_title('Bar Plot')

# Display the figure
plt.show()

# %%
import seaborn as sns

# Create a new DataFrame with value counts of experience_level
exp_counts = df['experience_level'].value_counts()

# Convert value counts to list
values = exp_counts.values.tolist()

# Convert index (i.e. experience levels) to list
labels = exp_counts.index.tolist()

# Create a figure object of the size 18x6
fig = plt.figure(figsize=(18, 6))

# Add the pie chart
ax1 = fig.add_subplot(1, 3, 1)
ax1.pie(values, labels=labels, autopct='%1.1f%%')
ax1.set_title('Experience Level - Pie Chart')

# Add the bar chart
ax2 = fig.add_subplot(1, 3, 2)
ax2.bar(labels, values)
ax2.set_title('Experience Level - Bar Chart')

# Add the bar plot
ax3 = fig.add_subplot(1, 3, 3)
sns.barplot(x="experience_level", y="salary", data=df, ax=ax3)
ax3.set_title('Bar Plot')

# Adjust the subplot positions
fig.subplots_adjust(wspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()
# Which group has the most experience in total? pie, bar
#  Which group earns the most in total? bar plot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           4134 non-null   int64
#  1   experience_level    4134 non-null   object
#  2   employment_type     4134 non-null   object
#  3   job_title           4134 non-null   object
#  4   salary              4134 non-null   int64
#  5   salary_currency     4134 non-null   object
#  6   salary_in_usd       4134 non-null   int64
#  7   employee_residence  4134 non-null   object
#  8   remote_ratio        4134 non-null   int64
#  9   company_location    4134 non-null   object
#  10  company_size        4134 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 355.4+ KB

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              FT        AWS Data Architect
# 1          2023               SE              FT            Data Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT             Data Engineer
# 4          2023               SE              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 4129       2020               SE              FT            Data Scientist
# 4130       2021               MI              FT  Principal Data Scientist
# 4131       2020               EN              FT            Data Scientist
# 4132       2020               EN              CT     Business Data Analyst
# 4133       2021               SE              FT      Data Science Manager
#
# ...

# %%
import seaborn as sns

# Create a new DataFrame with value counts of experience_level
exp_counts = df['experience_level'].value_counts()

# Convert value counts to list
values = exp_counts.values.tolist()

# Convert index (i.e. experience levels) to list
labels = exp_counts.index.tolist()

# Create a figure object of the size 18x6
fig = plt.figure(figsize=(18, 6))

# Add the pie chart
ax1 = fig.add_subplot(1, 3, 1)
sns.barplot(x="experience_level", y="remote_ratio", data=df, ax=ax1)
ax1.set_title('Experience Level & Remote Ratio - Bar Plot')

# Add the count plot
ax2 = fig.add_subplot(1, 3, 2)
sns.countplot(x="experience_level", data=df, ax=ax2)
ax2.set_title('Experience Level Count')

# Add the bar plot
ax3 = fig.add_subplot(1, 3, 3)
sns.barplot(x="experience_level", y="salary", data=df, ax=ax3)
ax3.set_title('Experience Level & Salary - Bar Plot')

# Adjust the subplot positions
fig.subplots_adjust(wspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()
# experience level vs remote rate -1
# number of experience levels - 2
# relationship between experience level and salary

# %%
import seaborn as sns

# Create a figure object of the size 18x18
fig = plt.figure(figsize=(18, 18))

# Add the first subplot for company_location
ax1 = fig.add_subplot(3, 1, 1)
sns.countplot(x="company_location", data=df, ax=ax1)
ax1.set_title('Company Location Count')

# Add the second subplot for employment_type
ax2 = fig.add_subplot(3, 1, 2)
sns.countplot(x="employment_type", data=df, ax=ax2)
ax2.set_title('Employment Type Count')

# Add the third subplot for company_size
ax3 = fig.add_subplot(3, 1, 3)
sns.countplot(x="company_size", data=df, ax=ax3)
ax3.set_title('Company Size Count')

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()

# %%
import seaborn as sns

# Create a figure object of the size 18x18
fig = plt.figure(figsize=(18, 18))

# Add the first subplot for company_location
ax1 = fig.add_subplot(3, 1, 1)
sns.countplot(x="company_location", data=df, ax=ax1)
ax1.set_title('Company Location Count')
ax1.set_ylim([0, 1500])

# Add the second subplot for employment_type
ax2 = fig.add_subplot(3, 1, 2)
sns.countplot(x="employment_type", data=df, ax=ax2)
ax2.set_title('Employment Type Count')
ax2.set_ylim([0, 1500])

# Add the third subplot for company_size
ax3 = fig.add_subplot(3, 1, 3)
sns.countplot(x="company_size", data=df, ax=ax3)
ax3.set_title('Company Size Count')
ax3.set_ylim([0, 1500])

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()

# %%
import seaborn as sns

# Get the top 5 company locations with highest frequency
top_locations = df['company_location'].value_counts().nlargest(5).index.tolist()

# Create a figure object of the size 18x10
fig = plt.figure(figsize=(18, 10))

# Add the first subplot for the top 5 company locations
ax1 = fig.add_subplot(2, 1, 1)
sns.countplot(x="company_location", data=df[df['company_location'].isin(top_locations)], ax=ax1)
ax1.set_title('Top 5 Company Locations Count')

# Add the second subplot for the remaining company locations
ax2 = fig.add_subplot(2, 1, 2)
sns.countplot(x="company_location", data=df[~df['company_location'].isin(top_locations)], ax=ax2)
ax2.set_title('Other Company Locations Count')

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()

# %%
import seaborn as sns

# Create a figure object of the size 18x18
fig = plt.figure(figsize=(18, 18))

# Add the first subplot for company_location
ax1 = fig.add_subplot(3, 1, 1)
sns.countplot(x="company_location", data=df, ax=ax1)
ax1.set_title('Company Location Count')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45, ha="right")

# Add the second subplot for employment_type
ax2 = fig.add_subplot(3, 1, 2)
sns.countplot(x="employment_type", data=df, ax=ax2)
ax2.set_title('Employment Type Count')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45, ha="right")

# Add the third subplot for company_size
ax3 = fig.add_subplot(3, 1, 3)
sns.countplot(x="company_size", data=df, ax=ax3)
ax3.set_title('Company Size Count')
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=45, ha="right")

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()

# %%
import seaborn as sns

# Get the top 5 company locations with highest frequency
top_locations = df['company_location'].value_counts().nlargest(5).index.tolist()

# Create a figure object of the size 18x10
fig, axes = plt.subplots(nrows=2, figsize=(18, 10))

# Add the first subplot for the top 5 company locations
sns.countplot(x="company_location", data=df[df['company_location'].isin(top_locations)], ax=axes[0])
axes[0].set_title('Top 5 Company Locations Count')

# Add the second subplot for the remaining company locations
sns.countplot(x="company_location", data=df[~df['company_location'].isin(top_locations)], ax=axes[1])
axes[1].set_title('Other Company Locations Count')

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()

# %%
df.describe()
# Out:
#          work_year        salary  salary_in_usd  remote_ratio
# count  4134.000000  4.134000e+03    4134.000000   4134.000000
# mean   2022.428882  1.894287e+05  139416.264393     45.936139
# std       0.684520  6.460075e+05   63605.472000     48.624255
# min    2020.000000  6.000000e+03    5132.000000      0.000000
# 25%    2022.000000  1.000000e+05   96817.000000      0.000000
# 50%    2023.000000  1.400000e+05  136000.000000      0.000000
# 75%    2023.000000  1.833100e+05  179820.000000    100.000000
# max    2023.000000  3.040000e+07  450000.000000    100.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True);

# %%
sns.scatterplot(x ="salary", y="salary_in_usd", data=df);

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2023               MI              FT  AWS Data Architect  258000
# 1       2023               SE              FT      Data Scientist  225000
# 2       2023               SE              FT      Data Scientist  156400
# 3       2023               SE              FT       Data Engineer  190000
# 4       2023               SE              FT       Data Engineer  150000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         258000                 US           100
# 1             USD         225000                 US             0
# 2             USD         156400                 US             0
# 3             USD         190000                 US           100
# 4             USD         150000                 US           100
#
#   company_location company_size
# 0               US            L
# 1               US            M
# ...

# %%
sns.barplot(x="employment_type", y ="salary", data = df);

# %%
df["employment_type"].value_counts()
# Out:
# FT    4093
# PT      17
# CT      13
# FL      11
# Name: employment_type, dtype: int64
