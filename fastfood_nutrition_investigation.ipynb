# %% [markdown]
# <a href="https://colab.research.google.com/github/huseyincenik/statistics/blob/main/fastfood_nutrition_investigation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Welcome to the Fast Food Nutrition Dataset, which provides a comprehensive breakdown of the nutritional content of various fast food products from popular fast food chains.
#
# Fast food is known for its convenience and affordability, but it is also infamous for its high-calorie, high-fat, and high-sugar content. This dataset aims to shed light on the nutritional value of these fast food products, helping consumers make more informed decisions about their food choices.
#
# With information on calories, fat, carbohydrates, protein, and other key nutrients, this dataset provides a valuable resource for nutritionists, researchers, and health-conscious individuals. By analyzing this dataset, we can gain a better understanding of the nutritional impact of fast food consumption and work towards creating healthier food options in the fast food industry.
#
# https://www.kaggle.com/datasets/ulrikthygepedersen/fastfood-nutrition

# %%
df = pd.read_csv('fastfood.csv')

# %%
df.head(5)
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 0          7      2.0        0.0           95    1110          44    3.0
# 1         45     17.0        1.5          130    1580          62    2.0
# 2         67     27.0        3.0          220    1920          63    3.0
# 3         31     10.0        0.5          155    1940          62    2.0
# 4         45     12.0        0.5          120    1980          81    4.0
#
#    sugar  protein  vit_a  vit_c  calcium  salad
# ...

# %%
df.dtypes
# Out:
# restaurant      object
# item            object
# calories         int64
# cal_fat          int64
# total_fat        int64
# sat_fat        float64
# trans_fat      float64
# cholesterol      int64
# sodium           int64
# total_carb       int64
# fiber          float64
# sugar            int64
# protein        float64
# vit_a          float64
# vit_c          float64
# calcium        float64
# salad           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   restaurant   515 non-null    object
#  1   item         515 non-null    object
#  2   calories     515 non-null    int64
#  3   cal_fat      515 non-null    int64
#  4   total_fat    515 non-null    int64
#  5   sat_fat      515 non-null    float64
#  6   trans_fat    515 non-null    float64
#  7   cholesterol  515 non-null    int64
#  8   sodium       515 non-null    int64
#  9   total_carb   515 non-null    int64
#  10  fiber        503 non-null    float64
#  11  sugar        515 non-null    int64
#  12  protein      514 non-null    float64
#  13  vit_a        301 non-null    float64
#  14  vit_c        305 non-null    float64
#  15  calcium      305 non-null    float64
#  16  salad        515 non-null    object
# dtypes: float64(7), int64(7), object(3)
# memory usage: 68.5+ KB

# %%
df.isnull().sum() # Features with a value of 0
# Out:
# restaurant       0
# item             0
# calories         0
# cal_fat          0
# total_fat        0
# sat_fat          0
# trans_fat        0
# cholesterol      0
# sodium           0
# total_carb       0
# fiber           12
# sugar            0
# protein          1
# vit_a          214
# vit_c          210
# calcium        210
# salad            0
# dtype: int64

# %%
sns.heatmap(df.isnull(),cbar = False);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   restaurant   515 non-null    object
#  1   item         515 non-null    object
#  2   calories     515 non-null    int64
#  3   cal_fat      515 non-null    int64
#  4   total_fat    515 non-null    int64
#  5   sat_fat      515 non-null    float64
#  6   trans_fat    515 non-null    float64
#  7   cholesterol  515 non-null    int64
#  8   sodium       515 non-null    int64
#  9   total_carb   515 non-null    int64
#  10  fiber        503 non-null    float64
#  11  sugar        515 non-null    int64
#  12  protein      514 non-null    float64
#  13  vit_a        301 non-null    float64
#  14  vit_c        305 non-null    float64
#  15  calcium      305 non-null    float64
#  16  salad        515 non-null    object
# dtypes: float64(7), int64(7), object(3)
# memory usage: 68.5+ KB

# %%
df.dropna()
# Out:
#     restaurant                                       item  calories  cal_fat  \
# 0    Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1    Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2    Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3    Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4    Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
# ..         ...                                        ...       ...      ...
# 502  Taco Bell                          Chicken Quesalupa       440      200
# 503  Taco Bell                             Beef Quesalupa       460      240
# 507  Taco Bell                                    Stacker       390      170
# 509  Taco Bell          Original Triple Double Crunchwrap       700      270
# 510  Taco Bell             Spicy Triple Double Crunchwrap       780      340
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515 entries, 0 to 514
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   restaurant   515 non-null    object
#  1   item         515 non-null    object
#  2   calories     515 non-null    int64
#  3   cal_fat      515 non-null    int64
#  4   total_fat    515 non-null    int64
#  5   sat_fat      515 non-null    float64
#  6   trans_fat    515 non-null    float64
#  7   cholesterol  515 non-null    int64
#  8   sodium       515 non-null    int64
#  9   total_carb   515 non-null    int64
#  10  fiber        503 non-null    float64
#  11  sugar        515 non-null    int64
#  12  protein      514 non-null    float64
#  13  vit_a        301 non-null    float64
#  14  vit_c        305 non-null    float64
#  15  calcium      305 non-null    float64
#  16  salad        515 non-null    object
# dtypes: float64(7), int64(7), object(3)
# memory usage: 68.5+ KB

# %%
sns.scatterplot(x ="protein", y="total_fat", data=df);  
# What is the relationship between the amount of protein and fat?
# Scatterplot can be used if there are two numeric variables.

# %%
df["protein"].corr(df["total_fat"])
# Out:
# 0.7195175056554599

# %%
sns.scatterplot(x ="protein", y="vit_a", data=df);

# %%
df["protein"].corr(df["vit_a"]) #  there is a negative weak correlation
# Out:
# -0.04942281482724181

# %%
sns.scatterplot(x ="calories", y="sodium", data=df);

# %%
df["calories"].corr(df["sodium"]) # a relatively strong positive correlation
# Out:
# 0.8178545469831601

# %%
df.corr()
# Out:
# <ipython-input-26-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              calories   cal_fat  total_fat   sat_fat  trans_fat  cholesterol  \
# calories     1.000000  0.901661   0.900494  0.739664   0.530354     0.762460
# cal_fat      0.901661  1.000000   0.995311  0.852150   0.648422     0.803997
# total_fat    0.900494  0.995311   1.000000  0.846716   0.648821     0.801352
# sat_fat      0.739664  0.852150   0.846716  1.000000   0.812126     0.764030
# trans_fat    0.530354  0.648422   0.648821  0.812126   1.000000     0.680858
# cholesterol  0.762460  0.803997   0.801352  0.764030   0.680858     1.000000
# sodium       0.817855  0.670458   0.669182  0.487456   0.261466     0.596164
# total_carb   0.712701  0.419373   0.422543  0.276534   0.100284     0.238728
# ...

# %%
df.restaurant.unique()
# Out:
# array(['Mcdonalds', 'Chick Fil-A', 'Sonic', 'Arbys', 'Burger King',
#        'Dairy Queen', 'Subway', 'Taco Bell'], dtype=object)

# %%
sns.countplot(x = "restaurant", data=df); # Which restaurant has more observations?

# %%
df.restaurant.value_counts()
# Out:
# Taco Bell      115
# Subway          96
# Burger King     70
# Mcdonalds       57
# Arbys           55
# Sonic           53
# Dairy Queen     42
# Chick Fil-A     27
# Name: restaurant, dtype: int64

# %%
sns.barplot(x = "restaurant", y = "calories", data=df) 
# Which restaurant has the most calories in fast food?
# Out:
# <Axes: xlabel='restaurant', ylabel='calories'>

# %%
df.describe()
# Out:
#           calories      cal_fat   total_fat     sat_fat   trans_fat  \
# count   515.000000   515.000000  515.000000  515.000000  515.000000
# mean    530.912621   238.813592   26.590291    8.153398    0.465049
# std     282.436147   166.407510   18.411876    6.418811    0.839644
# min      20.000000     0.000000    0.000000    0.000000    0.000000
# 25%     330.000000   120.000000   14.000000    4.000000    0.000000
# 50%     490.000000   210.000000   23.000000    7.000000    0.000000
# 75%     690.000000   310.000000   35.000000   11.000000    1.000000
# max    2430.000000  1270.000000  141.000000   47.000000    8.000000
#
#        cholesterol       sodium  total_carb       fiber       sugar  \
# count   515.000000   515.000000  515.000000  503.000000  515.000000
# mean     72.456311  1246.737864   45.664078    4.137177    7.262136
# std      63.160406   689.954278   24.883342    3.037460    6.761301
# min       0.000000    15.000000    0.000000    0.000000    0.000000
# ...

# %%
sns.histplot(x ="sugar", data=df); # Displays the frequency of the sugar numerical variable.

# %%
df.sugar.value_counts()
# Out:
# 7     53
# 4     50
# 6     49
# 5     45
# 3     41
# 8     39
# 1     37
# 9     31
# 2     28
# 0     26
# 16    21
# 14    15
# 11    14
# 12    14
# 10    14
# 13     9
# 18     9
# 15     4
# 24     2
# 17     2
# 19     2
# 34     1
# 36     1
# 30     1
# 37     1
# 35     1
# 20     1
# 23     1
# 87     1
# 52     1
# 22     1
# Name: sugar, dtype: int64

# %%
sns.boxplot(x = "sugar", data = df) # sugar numeric variable boxplot
# Out:
# <Axes: xlabel='sugar'>

# %%
sns.histplot(x = "fiber", data=df); 
# mean > median , mean = 4.13 , median = 3 and 1.25 < mod < 2.5 #hist and box are used for numeric data.

# %%
sns.boxplot(x = "fiber", data= df); #  there are outliers

# %%
df.describe()
# Out:
#           calories      cal_fat   total_fat     sat_fat   trans_fat  \
# count   515.000000   515.000000  515.000000  515.000000  515.000000
# mean    530.912621   238.813592   26.590291    8.153398    0.465049
# std     282.436147   166.407510   18.411876    6.418811    0.839644
# min      20.000000     0.000000    0.000000    0.000000    0.000000
# 25%     330.000000   120.000000   14.000000    4.000000    0.000000
# 50%     490.000000   210.000000   23.000000    7.000000    0.000000
# 75%     690.000000   310.000000   35.000000   11.000000    1.000000
# max    2430.000000  1270.000000  141.000000   47.000000    8.000000
#
#        cholesterol       sodium  total_carb       fiber       sugar  \
# count   515.000000   515.000000  515.000000  503.000000  515.000000
# mean     72.456311  1246.737864   45.664078    4.137177    7.262136
# std      63.160406   689.954278   24.883342    3.037460    6.761301
# min       0.000000    15.000000    0.000000    0.000000    0.000000
# ...

# %%
df.head(5)
# Out:
#   restaurant                                       item  calories  cal_fat  \
# 0  Mcdonalds           Artisan Grilled Chicken Sandwich       380       60
# 1  Mcdonalds             Single Bacon Smokehouse Burger       840      410
# 2  Mcdonalds             Double Bacon Smokehouse Burger      1130      600
# 3  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750      280
# 4  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920      410
#
#    total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  fiber  \
# 0          7      2.0        0.0           95    1110          44    3.0
# 1         45     17.0        1.5          130    1580          62    2.0
# 2         67     27.0        3.0          220    1920          63    3.0
# 3         31     10.0        0.5          155    1940          62    2.0
# 4         45     12.0        0.5          120    1980          81    4.0
#
#    sugar  protein  vit_a  vit_c  calcium  salad
# ...
