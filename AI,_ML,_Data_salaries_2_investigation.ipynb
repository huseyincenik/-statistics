# %% [markdown]
# <a href="https://colab.research.google.com/github/huseyincenik/statistics/blob/main/AI%2C_ML%2C_Data_salaries_2_investigation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv('salaries.csv')

# %%
df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              FT        AWS Data Architect
# 1          2023               SE              FT            Data Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT             Data Engineer
# 4          2023               SE              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 4129       2020               SE              FT            Data Scientist
# 4130       2021               MI              FT  Principal Data Scientist
# 4131       2020               EN              FT            Data Scientist
# 4132       2020               EN              CT     Business Data Analyst
# 4133       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# **Introduction**
#
# 💬 "Salary for AI, ML Data jobs" is one of the fascinating practical topics, currently receiving great attention from the community of people studying and working in the field of Data Science.
#
# Helping those interested in the field of Data Science:
#
# Get an overview of the changes in this field from 2020 to the present.
#
# Capture the trend of working and salary between industries going on in the world.
#
# Provide a lot of useful information to give directions on future work.
#
# About dataset
#
# The data source is available with a worldwide contribution size, being collected and updated continuously from 2020 to the present time (usually on a weekly basis). The dataset is published in the public domain, users can access and download the dataset easily.
#
# Column meaning
#
# work_year: The year the salary was paid.
#
# experience_level: The experience level in the job during the year with the following possible values
#
# EN Entry-level
#
# MI Junior Mid-level
#
# SE Intermediate Senior-level
#
# EX Expert Executive-level / Director
#
# employment_type: The type of employment for the role
#
# PT Part-time
#
# FT Full-time
#
# CT Contract
#
# FL Freelance
#
# job_title: The role worked in during the year.
#
# salary: The total gross salary amount paid.
#
# salary_currency: The currency of the salary paid as an ISO 4217 currency code.
#
# salary_in_usd: The salary in USD (FX rate divided by avg. USD rate for the respective year via fxdata.foorilla.com.
#
# employee_residence: Employee's primary country of residence in during the work year as an ISO 3166 country code.
#
# remote_ratio: The overall amount of work done remotely, possible values are as follows
#
# 0 No remote work (less than 20%)
#
# 50 Partially remote
#
# 100 Fully remote (more than 80%)
#
# company_location: The country of the employer's main office or contracting
# branch as an ISO 3166 country code.
#
# company_size: The average number of people that worked for the company during
# the year
#
# S less than 50 employees (small)
#
# M 50 to 250 employees (medium)
#
# L more than 250 employees (large)
#
# https://www.kaggle.com/datasets/nguyenthicamlai/ai-ml-data-salaries

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           4134 non-null   int64
#  1   experience_level    4134 non-null   object
#  2   employment_type     4134 non-null   object
#  3   job_title           4134 non-null   object
#  4   salary              4134 non-null   int64
#  5   salary_currency     4134 non-null   object
#  6   salary_in_usd       4134 non-null   int64
#  7   employee_residence  4134 non-null   object
#  8   remote_ratio        4134 non-null   int64
#  9   company_location    4134 non-null   object
#  10  company_size        4134 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 355.4+ KB

# %%
df.head(5)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2023               MI              FT  AWS Data Architect  258000
# 1       2023               SE              FT      Data Scientist  225000
# 2       2023               SE              FT      Data Scientist  156400
# 3       2023               SE              FT       Data Engineer  190000
# 4       2023               SE              FT       Data Engineer  150000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         258000                 US           100
# 1             USD         225000                 US             0
# 2             USD         156400                 US             0
# 3             USD         190000                 US           100
# 4             USD         150000                 US           100
#
#   company_location company_size
# 0               US            L
# 1               US            M
# ...

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.job_title.unique()
# Out:
# array(['AWS Data Architect', 'Data Scientist', 'Data Engineer',
#        'Applied Scientist', 'ML Engineer', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Manager',
#        'Product Data Analyst', 'Autonomous Vehicle Operations Lead',
#        'Applied Machine Learning Engineer', 'Analytics Engineer',
#        'ETL Developer', 'Business Intelligence Engineer',
#        'BI Data Analyst', 'Machine Learning Developer',
#        'Research Engineer', 'Data Integration Specialist',
#        'Data Architect', 'BI Developer', 'Data Visualization Analyst',
#        'Head of Data', 'Autonomous Vehicle Technician', 'Data Modeler',
#        'Sales Data Analyst', 'Cloud Data Engineer',
#        'Finance Data Analyst', 'Research Scientist',
#        'Data Analytics Manager', 'Data Specialist',
#        'Data Operations Analyst', 'Director of Data Science',
#        'Data Science Manager', 'Data Science Lead',
#        'Machine Learning Scientist', 'AI Scientist',
# ...

# %%
df.apply(lambda)

# %%
# 'Data Scientist', 
# 'Data Engineer',
# 'Applied Scientist', 
# 'ML Engineer', 
# 'Data Analyst',
# 'Machine Learning Engineer', 
# 'Data Manager',
# 'Data Specialist',
# data scientist - experience level - salary ,data, country , US merkezli bakalim . 
#'Data Scientist',

# %%
df_data = df[df["job_title"].apply(lambda x : 'data' in x.lower())]
df_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              FT        AWS Data Architect
# 1          2023               SE              FT            Data Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT             Data Engineer
# 4          2023               SE              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 4129       2020               SE              FT            Data Scientist
# 4130       2021               MI              FT  Principal Data Scientist
# 4131       2020               EN              FT            Data Scientist
# 4132       2020               EN              CT     Business Data Analyst
# 4133       2021               SE              FT      Data Science Manager
#
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3203 entries, 0 to 4133
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3203 non-null   int64
#  1   experience_level    3203 non-null   object
#  2   employment_type     3203 non-null   object
#  3   job_title           3203 non-null   object
#  4   salary              3203 non-null   int64
#  5   salary_currency     3203 non-null   object
#  6   salary_in_usd       3203 non-null   int64
#  7   employee_residence  3203 non-null   object
#  8   remote_ratio        3203 non-null   int64
#  9   company_location    3203 non-null   object
#  10  company_size        3203 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 300.3+ KB

# %%
df_data["job_title"].unique()
# Out:
# array(['AWS Data Architect', 'Data Scientist', 'Data Engineer',
#        'Data Analyst', 'Data Manager', 'Product Data Analyst',
#        'BI Data Analyst', 'Data Integration Specialist', 'Data Architect',
#        'Data Visualization Analyst', 'Head of Data', 'Data Modeler',
#        'Sales Data Analyst', 'Cloud Data Engineer',
#        'Finance Data Analyst', 'Data Analytics Manager',
#        'Data Specialist', 'Data Operations Analyst',
#        'Director of Data Science', 'Data Science Manager',
#        'Data Science Lead', 'Data Science Consultant',
#        'Business Data Analyst', 'Principal Data Scientist',
#        'Data Strategist', 'Compliance Data Analyst',
#        'Applied Data Scientist', 'Staff Data Analyst',
#        'Data DevOps Engineer', 'Data Quality Analyst',
#        'Big Data Engineer', 'Lead Data Analyst', 'BI Data Engineer',
#        'Lead Data Scientist', 'Cloud Database Engineer',
#        'Financial Data Analyst', 'Data Infrastructure Engineer',
# ...

# %%
df_data["job_title"].nunique()
# Out:
# 61

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('veriler.csv')

# "Data Scientist" iş unvanına sahip çalışanların tecrübelerine göre gruplandırın
ds_exp = df_data.groupby(['experience_level']).size()

# pasta grafiği için boyutları belirleyin
labels = ds_exp.index
sizes = ds_exp.values

# pasta grafiğini çizin
fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)

# grafiği görüntüleyin
plt.show()

# What level of experience do you have the most?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('veriler.csv')

# Group by experience of employees with the job title "Data Scientist"
ds_exp = df_data.groupby(['experience_level']).size()

# burst the slice of employees with the highest experience

explode = [0.5 if label == ds_exp.idxmin() else 0 for label in ds_exp.index]

# set the dimensions for the pie chart
labels = ds_exp.index
sizes = ds_exp.values

# draw the pie chart
fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(sizes, labels=labels, explode=explode, autopct='%1.1f%%', startangle=90)

# view chart
plt.show()

# %%
import pandas as pd

# df = pd.read_csv('veriler.csv')

# Group by experience of employees with the job title "Data Scientist"
ds_exp = df_data.groupby(['experience_level']).size()

# view chart
print(ds_exp)

""" 
It is not possible to make a definite interpretation as the meaning of each abbreviation may vary depending on the data source. 
However, considering that EN (Entry Level) positions are generally suitable for new graduates or employees with 1-2 years of experience,
 the following evaluations can be made as an approach:

EN (Entry Level): Employees with 0-2 years of experience
EX (Experienced): Employees with 2-5 years of experience
MI (Mid-Level): Employees with 5-10 years of experience
SE (Senior Level): Employees with more than 10 years of experience or in managerial positions.
"""
# Out:
# experience_level
# EN     238
# EX     111
# MI     685
# SE    2169
# dtype: int64

# %%
sns.countplot(x="work_year", data=df_data); # bar and pie charts are used for categorical data.
# Simple bar chart calculating frequency ( count bar chart)
# Which year has the most data?

# %%
import seaborn as sns

# Get the top 5 company locations with highest frequency
top_locations = df_data['company_location'].value_counts().nlargest(5).index.tolist()

# Create a figure object of the size 18x10
fig, axes = plt.subplots(nrows=2, figsize=(18, 10))

# Add the first subplot for the top 5 company locations
sns.countplot(x="company_location", data=df_data[df_data['company_location'].isin(top_locations)], ax=axes[0])
axes[0].set_title('Top 5 Company Locations Count')

# Add the second subplot for the remaining company locations
sns.countplot(x="company_location", data=df_data[~df_data['company_location'].isin(top_locations)], ax=axes[1])
axes[1].set_title('Other Company Locations Count')

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()

# %%
df_data_us = df_data[df_data["company_location"].apply(lambda x : 'US' in x.upper())]
df_data_us
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              FT        AWS Data Architect
# 1          2023               SE              FT            Data Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT             Data Engineer
# 4          2023               SE              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 4128       2021               SE              FT           Data Specialist
# 4129       2020               SE              FT            Data Scientist
# 4130       2021               MI              FT  Principal Data Scientist
# 4131       2020               EN              FT            Data Scientist
# 4132       2020               EN              CT     Business Data Analyst
#
# ...

# %%
df_data_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2647 entries, 0 to 4132
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           2647 non-null   int64
#  1   experience_level    2647 non-null   object
#  2   employment_type     2647 non-null   object
#  3   job_title           2647 non-null   object
#  4   salary              2647 non-null   int64
#  5   salary_currency     2647 non-null   object
#  6   salary_in_usd       2647 non-null   int64
#  7   employee_residence  2647 non-null   object
#  8   remote_ratio        2647 non-null   int64
#  9   company_location    2647 non-null   object
#  10  company_size        2647 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 248.2+ KB

# %%
import pandas as pd

# df = pd.read_csv('veriler.csv')

ds_exp = df_data_us.groupby(['experience_level']).size()

## view chart
print(ds_exp)
# Frequencies of US employees according to my experience


""" 
It is not possible to make a definite interpretation as the meaning of each abbreviation may vary depending on the data source. 
However, considering that EN (Entry Level) positions are generally suitable for new graduates or employees with 1-2 years of experience,
 the following evaluations can be made as an approach:

EN (Entry Level): Employees with 0-2 years of experience
EX (Experienced): Employees with 2-5 years of experience
MI (Mid-Level): Employees with 5-10 years of experience
SE (Senior Level): Employees with more than 10 years of experience or in managerial positions.
"""
# Out:
# experience_level
# EN     147
# EX      95
# MI     442
# SE    1963
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('veriler.csv')

# Group by experience of employees with the job title "Data Scientist"
ds_exp = df_data_us.groupby(['experience_level']).size()

# # burst the slice of employees with the highest experience

explode = [0.5 if label == ds_exp.idxmin() else 0 for label in ds_exp.index]

# set dimensions for pie chart
labels = ds_exp.index
sizes = ds_exp.values

# draw the pie chart
fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(sizes, labels=labels, explode=explode, autopct='%1.1f%%', startangle=90)

# view chart
plt.show()

# Pie chart of the frequencies of the employees working in us according to my experience


""" 
It is not possible to make a definite interpretation as the meaning of each abbreviation may vary depending on the data source. 
However, considering that EN (Entry Level) positions are generally suitable for new graduates or employees with 1-2 years of experience,
 the following evaluations can be made as an approach:

EN (Entry Level): Employees with 0-2 years of experience
EX (Experienced): Employees with 2-5 years of experience
MI (Mid-Level): Employees with 5-10 years of experience
SE (Senior Level): Employees with more than 10 years of experience or in managerial positions.
"""

# %%
import pandas as pd

# df = pd.read_csv('veriler.csv')

# Group by experience of employees with the "Data Scientist" job title
ds_exp = df_data_us[df_data_us['job_title'] == 'Data Scientist'].groupby(['experience_level']).size()

# view chart
print(ds_exp)

# Frequencies of data scientists working in US according to their experience


""" 
It is not possible to make a definite interpretation as the meaning of each abbreviation may vary depending on the data source. 
However, considering that EN (Entry Level) positions are generally suitable for new graduates or employees with 1-2 years of experience,
 the following evaluations can be made as an approach:

EN (Entry Level): Employees with 0-2 years of experience
EX (Experienced): Employees with 2-5 years of experience
MI (Mid-Level): Employees with 5-10 years of experience
SE (Senior Level): Employees with more than 10 years of experience or in managerial positions.
"""
# Out:
# experience_level
# EN     31
# EX     12
# MI     87
# SE    607
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('veriler.csv')

# Group by experience of employees with the "Data Scientist" job title
ds_exp = df_data_us[df_data_us['job_title'] == 'Data Scientist'].groupby(['experience_level']).size()

# blow the slice of employees with the most experience

explode = [0.5 if label == ds_exp.idxmin() else 0 for label in ds_exp.index]

# set dimensions for pie chart
labels = ds_exp.index
sizes = ds_exp.values

# # draw the pie chart
fig, ax = plt.subplots(figsize=(7, 7))
ax.pie(sizes, labels=labels, explode=explode, autopct='%1.1f%%', startangle=90)

# view chart
plt.show()
#
# pie chart according to the experience of data scientists working in us
# who has the most experience

# %%
df_data_us
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              FT        AWS Data Architect
# 1          2023               SE              FT            Data Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT             Data Engineer
# 4          2023               SE              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 4128       2021               SE              FT           Data Specialist
# 4129       2020               SE              FT            Data Scientist
# 4130       2021               MI              FT  Principal Data Scientist
# 4131       2020               EN              FT            Data Scientist
# 4132       2020               EN              CT     Business Data Analyst
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame for the specified job titles
job_titles = ['Data Scientist', 'Data Engineer', 'Applied Scientist', 'ML Engineer', 'Data Analyst',
              'Machine Learning Engineer', 'Data Manager', 'Data Specialist']
filtered_data = df_data_us[df_data_us['job_title'].isin(job_titles)]

# Create a figure object of the size 12x6
fig, ax = plt.subplots(figsize=(12, 6))

# Create a bar plot for salary by job title
sns.barplot(x="job_title", y="salary", data=filtered_data, ax=ax)
ax.set_title('Salary Comparison - Various Job Titles')
ax.set_xlabel('Job Title')
ax.set_ylabel('Salary')

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Display the figure
plt.show()

# Which title gets the highest salary in US?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame for the specified job titles
job_titles = ['Data Scientist', 'Data Engineer', 'Applied Scientist', 'ML Engineer', 'Data Analyst',
              'Machine Learning Engineer', 'Data Manager', 'Data Specialist']
filtered_data = df_data_us[df_data_us['job_title'].isin(job_titles)]

# Create a figure object of the size 12x6
fig, ax = plt.subplots(figsize=(12, 6))

# Create a bar plot for the distribution of experience levels by job title
sns.countplot(x="experience_level", hue="job_title", data=filtered_data, ax=ax)
ax.set_title('Experience Level Distribution - Various Job Titles')
ax.set_xlabel('Experience Level')
ax.set_ylabel('Count')

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Display the figure
plt.show()

# How can we compare the experience levels between these job titles?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame for the specified job titles
job_titles = ['Data Scientist', 'Data Engineer', 'Applied Scientist', 'ML Engineer', 'Data Analyst',
              'Machine Learning Engineer', 'Data Manager', 'Data Specialist']
filtered_data = df_data_us[df_data_us['job_title'].isin(job_titles)]

# Create a figure object of the size 12x6
fig, ax = plt.subplots(figsize=(12, 6))

# Create a bar plot for the remote ratio by job title
sns.barplot(x="job_title", y="remote_ratio", data=filtered_data, ax=ax)
ax.set_title('Remote Ratio Comparison - Various Job Titles')
ax.set_xlabel('Job Title')
ax.set_ylabel('Remote Ratio')

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Display the figure
plt.show()
# remote ratio comparison between job titles

# %%
import seaborn as sns

# Create a new DataFrame with value counts of experience_level
exp_counts = df_data_us['experience_level'].value_counts()

# Convert value counts to list
values = exp_counts.values.tolist()

# Convert index (i.e. experience levels) to list
labels = exp_counts.index.tolist()

# Create a figure object of the size 18x6
fig = plt.figure(figsize=(18, 6))

# Add the pie chart
ax1 = fig.add_subplot(1, 3, 1)
ax1.pie(values, labels=labels, autopct='%1.1f%%')
ax1.set_title('Experience Level - US - "Data" - Pie Chart')

# Add the bar chart
ax2 = fig.add_subplot(1, 3, 2)
ax2.bar(labels, values)
ax2.set_title('Experience Level - US - Bar Chart')

# Add the bar plot
ax3 = fig.add_subplot(1, 3, 3)
sns.barplot(x="experience_level", y="salary", data=df_data_us, ax=ax3)
ax3.set_title('US - Bar Plot')

# Adjust the subplot positions
fig.subplots_adjust(wspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()

# # Graphics of those in the US . Which person has the most experience, which experience earns the most salary?

# %%
import seaborn as sns
import matplotlib.gridspec as gridspec

# Filter the DataFrame for Data Scientist job title
ds_exp = df_data_us[df_data_us['job_title'] == 'Data Scientist']

# Create a new DataFrame with value counts of experience_level for Data Scientists
exp_counts = ds_exp['experience_level'].value_counts()

# Convert value counts to list
values = exp_counts.values.tolist()

# Convert index (i.e. experience levels) to list
labels = exp_counts.index.tolist()

# Create a figure object of the size 18x6
fig = plt.figure(figsize=(18, 6))

# Create a gridspec layout with 1 row and 3 columns
gs = gridspec.GridSpec(1, 3, width_ratios=[1, 1, 1])

# Add the bar chart
ax1 = fig.add_subplot(gs[0])
ax1.bar(labels, values)
ax1.set_title('Data Scientist - Experience Level - Bar Chart')

# Add the pie chart
ax2 = fig.add_subplot(gs[1])
ax2.pie(values, labels=labels, autopct='%1.1f%%')
ax2.set_title('Data Scientist - Experience Level - Pie Chart')

# Add the bar plot
ax3 = fig.add_subplot(gs[2])
sns.barplot(x="experience_level", y="salary", data=ds_exp, ax=ax3)
ax3.set_title('Data Scientist - Salary by Experience Level - Bar Plot')

# Adjust the subplot positions
fig.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()


# Graphs of data scientists in the US. Which person has the most experience, which experience earns the most salary?

# %%
import pandas as pd

# df = pd.read_csv('veriler.csv')

# "Data Scientist" iş unvanına sahip çalışanların tecrübelerine göre gruplandırın
ds_exp = df_data_us[df_data_us['job_title'] == 'Data Scientist'].groupby(['experience_level']).size()

# tabloyu görüntüleyin
print(ds_exp)

# Frequencies of data scientists working in us according to their experience
# Out:
# experience_level
# EN     31
# EX     12
# MI     87
# SE    607
# dtype: int64

# %%
import seaborn as sns
import matplotlib.gridspec as gridspec

# Filter the DataFrame for Data Scientist job title
ds_exp = df_data_us[df_data_us['job_title'] == 'Data Scientist']

# Create a new DataFrame with value counts of experience_level for Data Scientists
exp_counts_ds = ds_exp['experience_level'].value_counts()
exp_counts_all = df_data_us['experience_level'].value_counts()

# Convert value counts to lists
values_ds = exp_counts_ds.values.tolist()
values_all = exp_counts_all.values.tolist()

# Convert index (i.e. experience levels) to lists
labels = exp_counts_ds.index.tolist()

# Create a figure object of the size 18x6
fig = plt.figure(figsize=(18, 6))

# Create a gridspec layout with 1 row and 2 columns
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 1])

# Add the bar chart for Data Scientists
ax1 = fig.add_subplot(gs[0])
ax1.bar(labels, values_ds)
ax1.set_title('Data Scientist - Experience Level - Bar Chart')

# Add the bar chart for All Job Titles
ax2 = fig.add_subplot(gs[1])
ax2.bar(labels, values_all)
ax2.set_title('All Job Titles - Experience Level - Bar Chart')

# Adjust the subplot positions
fig.subplots_adjust(wspace=0.4)

# Display the figure
plt.show()
# How does the experience level compare between ds and all job titles?
# the graphic below is more detailed

# %%
import seaborn as sns
import matplotlib.gridspec as gridspec

# Create a new DataFrame with value counts of experience_level
exp_counts_all = df_data_us['experience_level'].value_counts()

# Convert value counts to list
values_all = exp_counts_all.values.tolist()

# Convert index (i.e. experience levels) to list
labels = exp_counts_all.index.tolist()

# Filter the DataFrame for Data Scientist job title
ds_exp = df_data_us[df_data_us['job_title'] == 'Data Scientist']

# Create a new DataFrame with value counts of experience_level for Data Scientists
exp_counts_ds = ds_exp['experience_level'].value_counts()

# Convert value counts to list
values_ds = exp_counts_ds.values.tolist()

# Create a figure object of the size 18x12
fig = plt.figure(figsize=(18, 12))

# Create a gridspec layout with 2 rows and 3 columns
gs = gridspec.GridSpec(2, 3, height_ratios=[1, 1], width_ratios=[1, 1, 1])

# Add the pie chart for all data
ax1 = fig.add_subplot(gs[0, 1])
ax1.pie(values_all, labels=labels, autopct='%1.1f%%')
ax1.set_title('Experience Level - US - "Data" - Pie Chart')

# Add the bar chart for all data
ax2 = fig.add_subplot(gs[0, 0])
ax2.bar(labels, values_all)
ax2.set_title('Experience Level - US - Bar Chart')

# Add the bar plot for all data
ax3 = fig.add_subplot(gs[0, 2])
sns.barplot(x="experience_level", y="salary", data=df_data_us, ax=ax3)
ax3.set_title('US - Bar Plot')

# Add the bar chart for Data Scientists
ax4 = fig.add_subplot(gs[1, 0])
ax4.bar(labels, values_ds)
ax4.set_title('Data Scientist - Experience Level - Bar Chart')

# Add the pie chart for Data Scientists
ax5 = fig.add_subplot(gs[1, 1])
ax5.pie(values_ds, labels=labels, autopct='%1.1f%%')
ax5.set_title('Data Scientist - Experience Level - Pie Chart')

# Add the bar plot for Data Scientists
ax6 = fig.add_subplot(gs[1, 2])
sns.barplot(x="experience_level", y="salary", data=ds_exp, ax=ax6)
ax6.set_title('Data Scientist - Salary by Experience Level - Bar Plot')

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, wspace=0.4, left=0.06, right=0.98)

# Display the figure
plt.show()

# %%
df_data_us
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               MI              FT        AWS Data Architect
# 1          2023               SE              FT            Data Scientist
# 2          2023               SE              FT            Data Scientist
# 3          2023               SE              FT             Data Engineer
# 4          2023               SE              FT             Data Engineer
# ...         ...              ...             ...                       ...
# 4128       2021               SE              FT           Data Specialist
# 4129       2020               SE              FT            Data Scientist
# 4130       2021               MI              FT  Principal Data Scientist
# 4131       2020               EN              FT            Data Scientist
# 4132       2020               EN              CT     Business Data Analyst
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a figure object of the size 18x12
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))

# Create bar plots for different variables
sns.barplot(x="company_size", y="salary", data=df_data_us, ax=axes[0, 0])
axes[0, 0].set_title('Salary by Company Size')

sns.barplot(x="employment_type", y="salary", data=df_data_us, ax=axes[0, 1])
axes[0, 1].set_title('Salary by Employment Type')

sns.barplot(x="salary_currency", y="salary", data=df_data_us, ax=axes[0, 2])
axes[0, 2].set_title('Salary by Salary Currency')

sns.barplot(x="work_year", y="salary", data=df_data_us, ax=axes[1, 0])
axes[1, 0].set_title('Salary by Work Year')

sns.barplot(x="experience_level", y="salary", data=df_data_us, ax=axes[1, 1])
axes[1, 1].set_title('Salary by Experience Level')

sns.barplot(x="remote_ratio", y="salary", data=df_data_us, ax=axes[1, 2])
axes[1, 2].set_title('Salary by Remote Ratio')

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Display the figure
plt.show()

# inr = indian rupee
# huf = hungarian forint
# INR 100 = $1.21
# 100 HUF = $0.29
# Let's compare all salaries .

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter the DataFrame for Data Scientist job title
ds_data = df_data_us[df_data_us['job_title'] == 'Data Scientist']

# Create a figure object of the size 18x12
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))

# Create bar plots for different variables
sns.barplot(x="company_size", y="salary", data=ds_data, ax=axes[0, 0])
axes[0, 0].set_title('Salary by Company Size (Data Scientist)')

sns.barplot(x="employment_type", y="salary", data=ds_data, ax=axes[0, 1])
axes[0, 1].set_title('Salary by Employment Type (Data Scientist)')

sns.barplot(x="salary_currency", y="salary", data=ds_data, ax=axes[0, 2])
axes[0, 2].set_title('Salary by Salary Currency (Data Scientist)')

sns.barplot(x="work_year", y="salary", data=ds_data, ax=axes[1, 0])
axes[1, 0].set_title('Salary by Work Year (Data Scientist)')

sns.barplot(x="experience_level", y="salary", data=ds_data, ax=axes[1, 1])
axes[1, 1].set_title('Salary by Experience Level (Data Scientist)')

sns.barplot(x="remote_ratio", y="salary", data=ds_data, ax=axes[1, 2])
axes[1, 2].set_title('Salary by Remote Ratio (Data Scientist)')

# Adjust the subplot positions
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Display the figure
plt.show()
# let's compare the data scientist salary job
